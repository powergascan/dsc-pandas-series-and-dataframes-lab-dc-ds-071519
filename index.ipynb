# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
#Your code here
df.columns=[i.lower() for i in df.columns]

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
#Your code here
df.set_index(df.index+1)
# Out:
#           c/a  unit       scp        station linename division        date  \
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 11       A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# ...

# %% [markdown]
# # Change the index back

# %%
# Your code here
df.reindex().head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Your code here
df['passthrough']=df.groupby(['station'])['linename'].transform('nunique')

df.sort_values(by='passthrough', inplace=True)
df[df['station']=="59 ST"].head(10)
# Out:
#       c/a  unit       scp station linename division        date      time  \
# 336  A002  R051  02-03-06   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 335  A002  R051  02-03-05   59 ST  NQR456W      BMT  08/31/2018  20:00:00
# 334  A002  R051  02-03-05   59 ST  NQR456W      BMT  08/31/2018  16:00:00
# 333  A002  R051  02-03-05   59 ST  NQR456W      BMT  08/31/2018  12:00:00
# 332  A002  R051  02-03-05   59 ST  NQR456W      BMT  08/31/2018  08:00:00
# 331  A002  R051  02-03-05   59 ST  NQR456W      BMT  08/31/2018  04:00:00
# 330  A002  R051  02-03-05   59 ST  NQR456W      BMT  08/31/2018  00:00:00
# 329  A002  R051  02-03-05   59 ST  NQR456W      BMT  08/30/2018  20:00:00
# 328  A002  R051  02-03-05   59 ST  NQR456W      BMT  08/30/2018  16:00:00
# 337  A002  R051  02-03-06   59 ST  NQR456W      BMT  08/25/2018  04:00:00
#
#         desc   entries  \
# 336  REGULAR   8623676
# 335  REGULAR  10976927
# 334  REGULAR  10976324
# 333  REGULAR  10975861
# 332  REGULAR  10975537
# ...

# %% [markdown]
# ## Write a function to clean a column name

# %%
def clean(col_name):
    cleaned = col_name.replace(r" ","")#Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'passthrough'],
#       dtype='object')

# %% [markdown]
# ## Group the Data by Day of Week and Plot the Sum of The Numeric Columns

# %%
df['date']=pd.to_datetime(df['date'])
#Your code here

# %%
df['weekday']=df['date'].dt.weekday

# %%
df.head()
# Out:
#           c/a  unit       scp          station linename division       date  \
# 98812    N528  R257  01-06-01    EAST BROADWAY        F      IND 2018-08-31
# 113980  PTH06  R546  00-00-08  PAVONIA/NEWPORT        1      PTH 2018-08-31
# 113981  PTH06  R546  00-00-08  PAVONIA/NEWPORT        1      PTH 2018-08-31
# 113982  PTH06  R546  00-00-08  PAVONIA/NEWPORT        1      PTH 2018-08-31
# 113983  PTH06  R546  00-00-09  PAVONIA/NEWPORT        1      PTH 2018-08-25
#
#             time     desc  entries    exits  passthrough  weekday
# 98812   08:00:00  REGULAR  3118060  2484444            1        4
# 113980  12:02:09  REGULAR   935646  1298481            1        4
# 113981  16:14:09  REGULAR   935967  1298959            1        4
# 113982  20:26:09  REGULAR   936279  1299823            1        4
# 113983  03:39:25  REGULAR   404642   330523            1        5

# %%
df_agg=df.groupby('weekday')[['entries','exits']].apply(lambda x: x.sum()).reset_index()
ax1 = df_agg.plot(kind='scatter', x='weekday', y='entries', color='r')    
ax2 = df_agg.plot(kind='scatter', x='weekday', y='exits', color='g', ax=ax1)  
plt.show()

# %% [markdown]
# ## Group the Data by Weekend/Weekday and Plot the Sum of the Numeric Columns

# %%
#Your code here

# %% [markdown]
# ## Analysis Question:
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
